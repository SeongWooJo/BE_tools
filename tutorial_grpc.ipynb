# %%
from gRPC.server.server import Server

grpc_server = Server()
grpc_server.start_server()
# Out:
# [*] Server started on port 50051
# See log in server_log.txt

# %%
import grpc
import gRPC.example_pb2 as pb2
import gRPC.example_pb2_grpc as pb2_grpc
from gRPC.client.interceptor import LoggingInterceptor


with grpc.insecure_channel('localhost:50051') as channel:
    interceptors = [LoggingInterceptor()]
    intercept_channel = grpc.intercept_channel(channel, *interceptors)
    stub = pb2_grpc.DataServiceStub(intercept_channel)
    
    # 데이터 생성
    request = pb2.DataRequest(
        # 1. Scalar: 일반 할당
        id=101,
        name="SeongWoo",
        value=99.9,
        active=True,
        
        # 2. Enum: 정의된 상수 사용
        current_status=pb2.DataRequest.COMPLETED
    )

    # 3. Repeated: .extend() 또는 .append() 사용 (직접 할당 불가) 리스트를 보낼 때 사용하는 방식
    request.tags.extend(["python", "grpc", "docker"])
    
    # 4. Map: 딕셔너리처럼 값 추가
    request.metadata["version"] = "1.0.0"
    request.metadata["env"] = "dev"

    # 요청 전송
    response = stub.SendData(request)
    print(f"[Result] {response.message} (Success: {response.success})")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 import gRPC.example_pb2 as pb2
#       3 import gRPC.example_pb2_grpc as pb2_grpc
# ----> 4 from gRPC.client.logger import LoggingInterceptor
#       7 with grpc.insecure_channel('localhost:50051') as channel:
#       8     interceptors = [LoggingInterceptor()]
#
# ImportError: cannot import name 'LoggingInterceptor' from 'gRPC.client.logger' (c:\Users\SeongWoo\Desktop\my_tools\BE_tools\gRPC\client\logger.py)

# %%
grpc_server.stop_server()
# Out:
# [*] gRPC Server stopped.
